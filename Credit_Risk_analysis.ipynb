# %% [markdown]
# # IMPORTING IMPORTANT LIBRARIES

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Loading the datasets in the form of DataFrame

# %%
loan_train = pd.read_csv('Training Data.csv')
loan_train = pd.DataFrame(loan_train)

# %%
loan_train
# Out:
#             Id   income  age  experience  married house_ownership  \
# 0            1  1303835   23           3   single          rented
# 1            2  7574516   40          10   single          rented
# 2            3  3991815   66           4  married          rented
# 3            4  6256451   41           2   single          rented
# 4            5  5768871   47          11   single          rented
# ...        ...      ...  ...         ...      ...             ...
# 251995  251996  8154883   43          13   single          rented
# 251996  251997  2843572   26          10   single          rented
# 251997  251998  4522448   46           7   single          rented
# 251998  251999  6507128   45           0   single          rented
# 251999  252000  9070230   70          17   single          rented
#
#        car_ownership           profession                 city  \
# 0                 no  Mechanical_engineer                 Rewa
# ...

# %%
loan_test1 = pd.read_csv('Test Data.csv')
loan_test = pd.DataFrame(loan_test)

# %%
loan_test
# Out:
#           id   income  age  experience  married house_ownership car_ownership  \
# 0          1  7393090   59          19   single          rented            no
# 1          2  1215004   25           5   single          rented            no
# 2          3  8901342   50          12   single          rented            no
# 3          4  1944421   49           9  married          rented           yes
# 4          5    13429   25          18   single          rented           yes
# ...      ...      ...  ...         ...      ...             ...           ...
# 27995  27996  9955481   57          13   single          rented            no
# 27996  27997  2917765   47           9   single          rented            no
# 27997  27998  8082415   24           5   single          rented            no
# 27998  27999  9474180   51          13   single          rented           yes
# 27999  28000  9250350   42           9   single          rented            no
#
# ...

# %% [markdown]
# # CONVERTING THE COLUMN'S DATA INTO PARTICULAR DATATYPE

# %%
loan_test["profession"]=pd.factorize(loan_test.profession)[0]
loan_test["city"]=pd.factorize(loan_test.city)[0]
loan_test["state"]=pd.factorize(loan_test.state)[0]
loan_test["married"]=pd.factorize(loan_test.married)[0]
loan_test["house_ownership"]=pd.factorize(loan_test.house_ownership)[0]
loan_test["car_ownership"]=pd.factorize(loan_test.car_ownership)[0]

# %%
loan_train["profession"]=pd.factorize(loan_train.profession)[0]
loan_train["city"]=pd.factorize(loan_train.city)[0]
loan_train["state"]=pd.factorize(loan_train.state)[0]
loan_train["married"]=pd.factorize(loan_train.married)[0]
loan_train["house_ownership"]=pd.factorize(loan_train.house_ownership)[0]
loan_train["car_ownership"]=pd.factorize(loan_train.car_ownership)[0]

# %%
loan_train
# Out:
#             Id   income  age  experience  married  house_ownership  \
# 0            1  1303835   23           3        0                0
# 1            2  7574516   40          10        0                0
# 2            3  3991815   66           4        1                0
# 3            4  6256451   41           2        0                0
# 4            5  5768871   47          11        0                0
# ...        ...      ...  ...         ...      ...              ...
# 251995  251996  8154883   43          13        0                0
# 251996  251997  2843572   26          10        0                0
# 251997  251998  4522448   46           7        0                0
# 251998  251999  6507128   45           0        0                0
# 251999  252000  9070230   70          17        0                0
#
#         car_ownership  profession  city  state  current_job_years  \
# 0                   0           0     0      0                  3
# ...

# %%
loan_test
# Out:
#           id   income  age  experience  married  house_ownership  \
# 0          1  7393090   59          19        0                0
# 1          2  1215004   25           5        0                0
# 2          3  8901342   50          12        0                0
# 3          4  1944421   49           9        1                0
# 4          5    13429   25          18        0                0
# ...      ...      ...  ...         ...      ...              ...
# 27995  27996  9955481   57          13        0                0
# 27996  27997  2917765   47           9        0                0
# 27997  27998  8082415   24           5        0                0
# 27998  27999  9474180   51          13        0                0
# 27999  28000  9250350   42           9        0                0
#
#        car_ownership  profession  city  state  current_job_years  \
# 0                  0           0     0      0                  4
# ...

# %%
X_train = loan_train.drop(['risk_flag'], axis = 1)
Y_train = loan_train['risk_flag']

# %%
X_train
# Out:
#             Id   income  age  experience  married  house_ownership  \
# 0            1  1303835   23           3        0                0
# 1            2  7574516   40          10        0                0
# 2            3  3991815   66           4        1                0
# 3            4  6256451   41           2        0                0
# 4            5  5768871   47          11        0                0
# ...        ...      ...  ...         ...      ...              ...
# 251995  251996  8154883   43          13        0                0
# 251996  251997  2843572   26          10        0                0
# 251997  251998  4522448   46           7        0                0
# 251998  251999  6507128   45           0        0                0
# 251999  252000  9070230   70          17        0                0
#
#         car_ownership  profession  city  state  current_job_years  \
# 0                   0           0     0      0                  3
# ...

# %%
Y_train = pd.DataFrame(Y_train)

# %%
Y_train
# Out:
#         risk_flag
# 0               0
# 1               0
# 2               0
# 3               1
# 4               1
# ...           ...
# 251995          0
# 251996          0
# 251997          0
# 251998          0
# 251999          0
#
# [252000 rows x 1 columns]

# %% [markdown]
# # BULDING THE CLASSIFIER

# %%
classifier = RandomForestClassifier(n_estimators = 500, criterion = 'gini', random_state=2)

# %% [markdown]
# # SPLITTING THE DATASET INTO TEST AND TRAIN

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.3, random_state = 2)

# %% [markdown]
# # FITTING THE DATA

# %%
classifier.fit(x_train, y_train)
# Out:
# <ipython-input-16-fdf0fc8db087>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   classifier.fit(x_train, y_train)
# RandomForestClassifier(n_estimators=500, random_state=2)

# %%
x_test
# Out:
#             Id   income  age  experience  married  house_ownership  \
# 221926  221927  5653048   61          16        0                0
# 212087  212088   156145   69           7        0                0
# 251277  251278  4498227   53          18        1                0
# 223297  223298  3230139   60          11        0                0
# 238193  238194  7429551   21           3        0                0
# ...        ...      ...  ...         ...      ...              ...
# 201886  201887   228131   30           5        0                0
# 214281  214282  5176469   45           2        0                0
# 38030    38031   854917   34           0        0                0
# 110132  110133  4971595   54           8        0                2
# 1414      1415  9299383   56          15        0                0
#
#         car_ownership  profession  city  state  current_job_years  \
# 221926              0          22    61      5                 11
# ...

# %% [markdown]
# # TESTING THE MODEL ON THE TRAINING SET FIRST

# %%
y_predict = classifier.predict(x_test)

# %%
y_test
# Out:
#         risk_flag
# 221926          0
# 212087          1
# 251277          0
# 223297          0
# 238193          0
# ...           ...
# 201886          0
# 214281          0
# 38030           0
# 110132          0
# 1414            1
#
# [75600 rows x 1 columns]

# %%
list(y_predict).count(1) + list(y_predict).count(0)
# Out:
# 75600

# %% [markdown]
# # IMPORTING ROC_AUC_SCORE TO CHECK ACCURACY

# %%
from sklearn.metrics import roc_auc_score

# %%
print("Accuracy of the model is ",round(roc_auc_score(y_test,y_predict)*100,2))
# Out:
# Accuracy of the model is  70.69

# %% [markdown]
# # Testing the MODEL on Test dataset and Predicting the Flag risk

# %%
Y_new = classifier.predict(loan_test)

# %%
list(Y_new).count(1)
# Out:
# 165

# %% [markdown]
# # Adding the Predicted risk_flag into our Dataset

# %%
loan_test1['risk_flag'] = Y_new

# %%
loan_test1['risk_flag'].value_counts()
# Out:
# 0    27835
# 1      165
# Name: risk_flag, dtype: int64

# %%
loan_test1.to_csv('Submission1.csv')

# %%
loan_test1 = loan_test1[0:38000]

# %%
sample = loan_test1.drop(['income','age','experience','married','house_ownership','car_ownership','profession','city','state','current_job_years','current_house_years'], axis = 1)

# %%
sample.to_csv('SUBMIT_DATASET_Pred.csv', index = False)

# %%
print("Number of Defaulters are ",list(Y_new).count(1),"\nThe Accuracy of the Model is ",round(roc_auc_score(y_test,y_predict),2))
# Out:
# Number of Defaulters are  165
# The Accuracy of the Model is  0.71
